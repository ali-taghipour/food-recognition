# %%
#!pip install .
# Out:
# Processing e:\projects\food-recognition\yolov10
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/60.8 kB 1.4 MB/s eta 0:00:01
#      -------------------- ------------------- 30.7/60.8 kB 1.4 MB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 404.2 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
# ...

# %%
import os
import urllib.request

# Create a directory for the weights in the current working directory
weights_dir = os.path.join(os.getcwd(), "weights")
os.makedirs(weights_dir, exist_ok=True)

# URLs of the weight files
urls = [
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10s.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10m.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10b.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10x.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10l.pt"
]

# Download each file
for url in urls:
    file_name = os.path.join(weights_dir, os.path.basename(url))
    urllib.request.urlretrieve(url, file_name)
    print(f"Downloaded {file_name}")
# Out:
# Downloaded E:\Projects\food-recognition\yolov10\weights\yolov10n.pt
# Downloaded E:\Projects\food-recognition\yolov10\weights\yolov10s.pt
# Downloaded E:\Projects\food-recognition\yolov10\weights\yolov10m.pt
# Downloaded E:\Projects\food-recognition\yolov10\weights\yolov10b.pt
# Downloaded E:\Projects\food-recognition\yolov10\weights\yolov10x.pt
# Downloaded E:\Projects\food-recognition\yolov10\weights\yolov10l.pt

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
# !yolo task=detect mode=train epochs=100 batch=16 plots=True model=weights/yolov10n.pt data=custom_data.yaml
# Out:
# New https://pypi.org/project/ultralytics/8.2.49 available ًںکƒ Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 ًںڑ€ Python-3.10.14 torch-2.3.0 CPU (13th Gen Intel Core(TM) i7-13700H)
# ...

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=runs/detect/train2/weights/best.pt source=test_images_1/veh2.jpg
